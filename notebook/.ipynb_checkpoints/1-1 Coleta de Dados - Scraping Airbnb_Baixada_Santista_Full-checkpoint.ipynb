# %% [markdown]
# # 1. Coleta de dados

# %% [markdown]
# ## 1. Scraping Baixada Santista

# %%
# Library
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# 2 opções de URL
urlperuibe = 'https://www.airbnb.com.br/s/Peru%C3%ADbe-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&query=Peru%C3%ADbe%20-%20SP&place_id=ChIJc-QAK7In0JQRNujVll8nevg&checkin=2021-03-05&checkout=2021-03-07&adults=2&source=structured_search_input_header&search_type=autocomplete_click'
#urlitanhaem = 'https://www.airbnb.com.br/s/Itanha%C3%A9m-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&query=Itanha%C3%A9m%20-%20SP&place_id=ChIJbTLym07Vz5QRywy4PRYDITI&checkin=2021-03-05&checkout=2021-03-07&adults=2&source=structured_search_input_header&search_type=autocomplete_click'
#urlbertioga='https://www.airbnb.com.br/s/Bertioga-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&query=Bertioga%20-%20SP&place_id=ChIJiRUBEuPwzZQRqK4IYuq7vDA&checkin=2021-03-05&checkout=2021-03-07&adults=2&source=structured_search_input_header&search_type=autocomplete_click'
#urlmongagua = 'https://www.airbnb.com.br/s/Mongagu%C3%A1-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-03-05&checkout=2021-03-07&adults=2&source=structured_search_input_header&search_type=filter_change&place_id=ChIJeWs4uoMozpQRuczAxh-pHSE'
#urlpraiagrande = 'https://www.airbnb.com.br/s/Praia-Grande-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&query=Praia%20Grande%20-%20SP&place_id=ChIJ5VC_2Z0fzpQRUbsj9l9MtIM&checkin=2021-03-05&checkout=2021-03-07&adults=2&source=structured_search_input_header&search_type=autocomplete_click'
#urlguaruja = 'https://www.airbnb.com.br/s/Guaruj%C3%A1-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-03-05&checkout=2021-03-07&adults=2&source=structured_search_input_header&search_type=filter_change&place_id=ChIJqz5zC0IAzpQRFBOscfZ3I_Q'
#urlsantos = 
# Vamos trabalhar com esta:
#url=urlsantos


url=urlperuibe

# Para enganar o site, permutaremos entre 2 opções de assinaturas de browser.
# Peguei de https://developers.whatismybrowser.com/
userAgents=[
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/74.0.3729.157 Safari/537.36",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.1.1 Safari/605.1.15"
]

# %%
# Use o requests para fazer uma operação HTTP GET e obter o HTML da página.
doc = requests.get(url.format(npagina=1), headers={"User-agent": userAgents[1]})

# %%
# Vamos verificar o que o webserver retornou olhando só os 700 primeiros bytes (variavel olhadinha).
olhadinha=700
print(str(doc.content[:olhadinha]) + '…')
# Out:
# b'<!doctype html>\n<html data-is-hyperloop="true" lang="pt" dir="ltr" xmlns:fb="http://ogp.me/ns/fb#"><head><script>window.sherlock_firstbyte = window.performance && window.performance.timing ? window.performance.timing.responseStart : Number(new Date());</script><script>!function(){"use strict";const n="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+/",o=new RegExp(`^\\\\d{10}_[${n}]{16}$`);const e=/(?:^| )bev=(.*?)(?:;|$)/;let t=!1;function c(){if(t||"undefined"==typeof document)return null;t=!0;const n=(document.cookie||"").match(e);if(!n||2!==n.length)return null;const c=decodeURIComponent(n[1]);return function(n){return o.test(n)}(c)?c:null}!function(){try{if(window.bev=windo'…

# %%
#O código "200" na resposta do servidor, se refere a uma resposta "OK" (ou sem erros)
doc.status_code
# Out:
# 200

# %% [markdown]
# # Analisar o HTML

# %%
analizador.clear()
analizador

# %%
analizador = BeautifulSoup(doc.content, 'html.parser')

# %%
imoveis.clear()
imoveis
# Out:
# []

# %%
# Então abaixo criaremos uma lista chamada imoveis que contém todos os trechos DOM que respeitam o nosso filtro:
imoveis = analizador.find_all('div', class_="_gig1e7")

# %%
for i in imoveis[:5]:
    print(str(i).replace("\n","").replace("   ","")[:200] + "…\n")
# Out:
# <div class="_gig1e7"><div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><meta content="Pousada SuíteQ p/3 c/Piscina e Ar Cond-100m do mar - null - Peruíbe " itemprop="n…
#
# <div class="_gig1e7"><div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><meta content="Edícula na Praia de Peruíbe/SP. - null - Jardim Peruibe" itemprop="name"/><meta c…
#
# <div class="_gig1e7"><div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><meta content="Peruibe com piscina, churrasqueira, frente a praia - null - Centro" itemprop="nam…
#
# <div class="_gig1e7"><div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><meta content='Suíte 3 "Aconchego" Piscina e Ar condicionado - null - Parque Balneario Oasis' it…
#
# ...

# %% [markdown]
# # url

# %%
#url = 'https://www.airbnb.com.br/s/Santos-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-02-12&checkout=2021-02 14&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJOxw7PEIDzpQRT2Rj_O3OTVg&federated_search_session_id=ff505cd4-5176-4dae-97cf-e4998b8e8b2c&items_offset=20&section_offset=3'

# %%
entrada.clear()
entrada
# Out:
# []

# %%
# dadas fim de semana
# Fevereiro
#entrada= [19, 26]
# Março
entrada= [5, 12, 19, 26]
# Abril
#entrada= [2, 9, 16, 23, 30]

# %%
pages.clear()
pages
# Out:
# []

# %%
# Criação de urls do mes de fevereiro
# E Looping com um range de vai de 0 a 300 intercando em 20 em 20.
pages = []
for i in range(0, 320, 20):
    for k in entrada:
        #Santos
        #fevereiro:
        #url = 'https://www.airbnb.com.br/s/Santos-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-02-'+ str(k) +'&checkout=2021-02-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJOxw7PEIDzpQRT2Rj_O3OTVg&federated_search_session_id=ff505cd4-5176-4dae-97cf-e4998b8e8b2c&items_offset=' + str(i) + '&section_offset=3'
        #março:
        #url = 'https://www.airbnb.com.br/s/Santos-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-03-'+ str(k) +'&checkout=2021-03-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJOxw7PEIDzpQRT2Rj_O3OTVg&federated_search_session_id=ff505cd4-5176-4dae-97cf-e4998b8e8b2c&items_offset=' + str(i) + '&section_offset=3'
        #abril:
        #url = 'https://www.airbnb.com.br/s/Santos-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-04-'+ str(k) +'&checkout=2021-04-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJOxw7PEIDzpQRT2Rj_O3OTVg&federated_search_session_id=ff505cd4-5176-4dae-97cf-e4998b8e8b2c&items_offset=' + str(i) + '&section_offset=3'
        
        #Guarujá
        #fevereiro:
        #url = 'https://www.airbnb.com.br/s/Guaruj%C3%A1-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-02-'+ str(k) +'&checkout=2021-02-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJqz5zC0IAzpQRFBOscfZ3I_Q&federated_search_session_id=c23463bf-7a86-4684-9b13-20454a7f25ef&items_offset='+ str(i) +'&section_offset=3'
        #março:
        #url = 'https://www.airbnb.com.br/s/Guaruj%C3%A1-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-03-'+ str(k) +'&checkout=2021-03-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJqz5zC0IAzpQRFBOscfZ3I_Q&federated_search_session_id=c23463bf-7a86-4684-9b13-20454a7f25ef&items_offset='+ str(i) +'&section_offset=3'
        
        #Praia grande
        #url = 'https://www.airbnb.com.br/s/Praia-Grande-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-02-'+ str(k) +'&checkout=2021-02-&adul'+ str(k+2) +'ts=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJ5VC_2Z0fzpQRUbsj9l9MtIM&federated_search_session_id=325afcd6-400a-44d1-b36e-8b0e412f7e0e&items_offset='+ str(i) +'&section_offset=3'
        #url = 'https://www.airbnb.com.br/s/Praia-Grande-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-03-'+ str(k) +'&checkout=2021-03-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJ5VC_2Z0fzpQRUbsj9l9MtIM&federated_search_session_id=d6e8d0b4-19fd-4d31-aa06-ef722d71d915&items_offset='+ str(i) +'&section_offset=3'
        
        #Monguaguá:
        #url = 'https://www.airbnb.com.br/s/Mongagu%C3%A1-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-02-'+ str(k) +'&checkout=2021-02-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJeWs4uoMozpQRuczAxh-pHSE&federated_search_session_id=015345fe-3fc3-4f95-88bf-074b6f52914b&items_offset='+ str(i)+ '&section_offset=3'
        #url = 'https://www.airbnb.com.br/s/Mongagu%C3%A1-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-03-'+ str(k) +'&checkout=2021-03-'+str(k+2)+'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJeWs4uoMozpQRuczAxh-pHSE&federated_search_session_id=8cc53fc8-62dc-4d5a-9f72-83256b4fdb14&items_offset='+ str(i)+ '&section_offset=3'
        
        #Bertioga:
        #url = 'https://www.airbnb.com.br/s/Bertioga-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-02-'+ str(k) +'&checkout=2021-02-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJiRUBEuPwzZQRqK4IYuq7vDA&federated_search_session_id=7aa0e22c-c788-4c7e-9ca1-0609a136c2ea&items_offset='+ str(i) +'&section_offset=3'
        #url = 'https://www.airbnb.com.br/s/Bertioga-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-03-'+ str(k) +'&checkout=2021-03-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJiRUBEuPwzZQRqK4IYuq7vDA&federated_search_session_id=a99f1f30-d7a6-4ca3-bef3-fa2a4dd5fd9f&items_offset='+ str(i)+ '&section_offset=3'
        
        #Itanhaém:
        #url = 'https://www.airbnb.com.br/s/Itanha%C3%A9m-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-02-'+ str(k) +'&checkout=2021-02-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJbTLym07Vz5QRywy4PRYDITI&federated_search_session_id=2812b7df-e4cd-47d5-8a6b-60ffd716346a&items_offset='+str(i)+'&section_offset=3'
        #url = 'https://www.airbnb.com.br/s/Itanha%C3%A9m-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-03-'+ str(k)+ '&checkout=2021-03-'+ str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJbTLym07Vz5QRywy4PRYDITI&federated_search_session_id=57b4f842-08bf-4d5c-8fa3-48c230a7e099&items_offset='+ str(i) +'&section_offset=3'
        
        #Peruibe:
        #url = 'https://www.airbnb.com.br/s/Peru%C3%ADbe-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-02-'+str(k)+'&checkout=2021-02-'+str(k+2) +'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJc-QAK7In0JQRNujVll8nevg&federated_search_session_id=b2382d07-c4c8-41a8-99f4-f39ad424bc9a&items_offset='+ str(i)+'&section_offset=3'
        url = 'https://www.airbnb.com.br/s/Peru%C3%ADbe-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-03-'+str(k)+'&checkout=2021-03-'+ str(k+2)+'&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJc-QAK7In0JQRNujVll8nevg&federated_search_session_id=50243dcb-b72d-4d73-9f08-9119624f1e16&items_offset='+str(i)+'&section_offset=3'
        pages.append(url)

# %%
len(pages)
# Out:
# 64

# %%
pages[0]
# Out:
# 'https://www.airbnb.com.br/s/Peru%C3%ADbe-~-SP/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&checkin=2021-03-5&checkout=2021-03-7&adults=2&source=structured_search_input_header&search_type=pagination&place_id=ChIJc-QAK7In0JQRNujVll8nevg&federated_search_session_id=50243dcb-b72d-4d73-9f08-9119624f1e16&items_offset=0&section_offset=3'

# %%
print(imoveis[1].select('a'))
# Out:
# [<a aria-label="Edícula na Praia de Peruíbe/SP." class="_gjfol0" data-check-info-section="true" href="/rooms/30973729?adults=2&amp;check_in=2021-03-05&amp;check_out=2021-03-07&amp;previous_page_section_name=1000&amp;federated_search_id=54fe544c-fc6a-471e-99be-f214b0135d69" rel="noopener noreferrer" target="listing_30973729"></a>]

# %%
for link in imoveis[1].select("a"):
    print(link.get('href'))
# Out:
# /rooms/30973729?adults=2&check_in=2021-03-05&check_out=2021-03-07&previous_page_section_name=1000&federated_search_id=54fe544c-fc6a-471e-99be-f214b0135d69

# %%
for link in imoveis[1].select("a"):
    room = link.get('href')
    room = room.split('?')
    #quarto:
    print(room[0].replace('/rooms/', ' ').strip())
    room = room[1].split('&')
    #check-in:
    print(room[1].replace('check_in=', ' ').strip())
    #check-out:
    print(room[2].replace('check_out=', ' ').strip())
# Out:
# 30973729
# 2021-03-05
# 2021-03-07

# %%
imoveis_.clear()
imoveis_
# Out:
# []

# %% [markdown]
# # Função de Extração em Massa

# %%
# em rows guardo uma lista temporária de dicts de dados capturados, 1 dict por imóvel
imoveis_=[]

for pagina in imoveis:
    #print("Estou aqui: " + url.format(npagina=pagina))
    
    # pega a página do site pela internet
    for i in pages:
        doc = requests.get(i, headers={"User-agent": userAgents[1]})
    
        # analiza o HTML
        analizador = BeautifulSoup(doc.content, 'html.parser')

        # extrai somente a lista de imóveis (em HTML) usando o seletor descoberto no código da página
        imoveis = analizador.find_all('div', class_="_gig1e7")

        for unidade in imoveis:
            uni={}
            # extrai dado por dado segundo seus seletores...
            
            # id:
            for link in unidade.select("a"):
                rooms = link.get('href')
                rooms = rooms.split('?')
                uni['id'] = rooms[0].replace('/rooms/', ' ').strip()
                #quarto:
                rooms = rooms[1].split('&')
                #check-in:
                uni['check-in'] = rooms[1].replace('check_in=', ' ').strip()
                #check-out:
                uni['check-out'] = rooms[2].replace('check_out=', ' ').strip()
                
            
            # titulo 1:
            uni['titulo'] = unidade.find("div",class_="_tmwq9g").find("div",class_="_1jzvdu8").find("div",class_="_1tanv1h").find("div",class_="_b14dlit").contents[0].strip()

            # titulo 2:
            uni['titulo_2'] = unidade.find("div",class_="_tmwq9g").find("div",class_="_bzh5lkq").contents[0].strip()

            # atributo 1:
            try:
                uni['atributo_1']  = unidade.find("div",class_="_kqh46o").contents[0].strip()
            except (IndexError, ValueError, AttributeError):
                continue

            # atributo 2:
            try:
                uni['atributo_2'] = unidade.find("div",class_="_kqh46o").contents[2].strip()
            except (IndexError, ValueError, AttributeError):
                continue

            # atributo 3:
            try:
                uni['atributo_3'] = unidade.find("div",class_="_kqh46o").contents[4].strip()
            except (IndexError, ValueError, AttributeError):
                continue

            #atributo 4
            try:
                uni['atributo_4'] = unidade.find("div",class_="_kqh46o").contents[6].strip()
            except (IndexError, ValueError, AttributeError):
                continue
            
            #atributo 5
            try:
                uni['atributo_5'] = unidade.find_next("div", class_="_kqh46o",style="margin-top:4px").contents[0].strip()
            except (IndexError, ValueError, AttributeError):
                continue
            
             #atributo 6
            try:
                uni['atributo_6'] = unidade.find_next("div", class_="_kqh46o",style="margin-top:4px").contents[2].strip()
            except (IndexError, ValueError, AttributeError):
                continue
            
             #atributo 7:
            try:
                uni['atributo_7'] = unidade.find_next("div", class_="_kqh46o",style="margin-top:4px").contents[4].strip()
            except (IndexError, ValueError, AttributeError):
                continue
                
              #atributo 8:
            try:
                uni['atributo_8'] = unidade.find_next("div", class_="_kqh46o",style="margin-top:4px").contents[6].strip()
            except (IndexError, ValueError, AttributeError):
                continue
                    
            # avaliação:
            try: 
                uni['avaliação'] = unidade.find("span",class_="_18khxk1").find("span",class_="_10fy1f8").text.strip()
            except (IndexError, ValueError, AttributeError):
                continue
            
            # comentários:
            try:
                uni['comentários'] = unidade.find("span",class_="_18khxk1").find("span",class_="_a7a5sx").text.replace('(', '').replace(')', '').strip()
            except (IndexError, ValueError, AttributeError):
                continue
            
            # preço:
            try:
                uni['preço'] = unidade.find("span",class_="_olc9rf0").text.replace("R$", " ").strip()
            except (IndexError, ValueError, AttributeError):
                continue   
            
            # preço total:
            try:
                uni['preço_total'] = unidade.find("div",class_="_1c02cnn").text.replace("Total de R$", " ").replace("Ver detalhamento de preço", " ").strip()
            except (IndexError, ValueError, AttributeError):
                continue 
            
            # Superhost:
            try:
                uni['superhost'] = unidade.find("div",class_="_17bkx6k").contents[0].strip()
            except (IndexError, ValueError, AttributeError):
                continue
            
            
            # No final deste loop, o dict uni contém os dados de 1 imóvel, aí adiciono-o a uma lista de imóveis
            imoveis_.append(uni)

# %%
imoveis_
# Out:
# [{'id': '41129581',
#   'check-in': '2021-03-12',
#   'check-out': '2021-03-14',
#   'titulo': 'Quarto inteiro em Peruíbe',
#   'titulo_2': 'Pousada Suíte c/ Piscina e Ar Cond - 100m do mar',
#   'atributo_1': '2 hóspedes',
#   'atributo_2': '1 quarto',
#   'atributo_3': '1 cama',
#   'atributo_4': '1 banheiros privado',
#   'atributo_5': 'Wi-Fi',
#   'atributo_6': 'Ar-condicionado',
#   'atributo_7': 'Piscina',
#   'atributo_8': 'Estacionamento gratuito',
#   'avaliação': '4.91',
#   'comentários': '45',
#   'preço': '134',
#   'preço_total': '317',
#   'superhost': 'Raridade'},
#  {'id': '30973729',
#   'check-in': '2021-03-12',
#   'check-out': '2021-03-14',
#   'titulo': 'Casa de hóspedes inteira em Jardim Peruibe',
#   'titulo_2': 'Edícula na Praia de Peruíbe/SP.',
#   'atributo_1': '3 hóspedes',
#   'atributo_2': '1 quarto',
#   'atributo_3': '1 cama',
#   'atributo_4': '1 banheiro',
#   'atributo_5': 'Wi-Fi',
#   'atributo_6': 'Ar-condicionado',
#   'atributo_7': 'Cozinha',
# ...

# %%
# Crio um DataFrame vazio cujas colunas são as chaves de 1 unidade:
todosOsImoveis=pd.DataFrame(columns=uni.keys())
todosOsImoveis
# Out:
# Empty DataFrame
# Columns: [id, check-in, check-out, titulo, titulo_2, atributo_1, atributo_2, atributo_3, atributo_4, atributo_5, atributo_6, atributo_7, atributo_8, avaliação, comentários]
# Index: []

# %%
todosOsImoveis=todosOsImoveis.append(imoveis_)
todosOsImoveis.head(5)
# Out:
#          id    check-in   check-out  \
# 0  41129581  2021-03-12  2021-03-14
# 1  30973729  2021-03-12  2021-03-14
# 2  39122509  2021-03-12  2021-03-14
# 3  29684686  2021-03-12  2021-03-14
# 4  46690967  2021-03-12  2021-03-14
#
#                                        titulo  \
# 0                   Quarto inteiro em Peruíbe
# 1  Casa de hóspedes inteira em Jardim Peruibe
# 2    Quarto inteiro em Parque Balneario Oasis
# 3                     Casa inteira em Peruíbe
# 4    Quarto inteiro em Parque Balneario Oasis
#
#                                             titulo_2  atributo_1 atributo_2  \
# 0   Pousada Suíte c/ Piscina e Ar Cond - 100m do mar  2 hóspedes   1 quarto
# 1                    Edícula na Praia de Peruíbe/SP.  3 hóspedes   1 quarto
# 2  Suíte 4 "Aconchego "c/piscina,ar cond 100 M Praia  2 hóspedes   1 quarto
# 3                        Casa do Carlos  em Peruíbe.  4 hóspedes    Estúdio
# 4                     Suíte 7 varanda " Por do Sol "  2 hóspedes   1 quarto
#
# ...

# %%
# Checando duplicadas as linhas
print(f'Temos {todosOsImoveis.duplicated().sum()} linhas duplicadas')
# Out:
# Temos 689 linhas duplicadas

# %%
len(todosOsImoveis)
# Out:
# 966

# %%
# Drop das linhas dúplicadas
# manter a primeria linha
dados_extracao_ = todosOsImoveis.drop_duplicates(keep = 'first')

# %%
print(len(dados_extracao_))
# Out:
# 277

# %%
#airbnb_santos_fevereiro = todosOsImoveis.copy()

# %%
airbnb_peruibe_mar = dados_extracao_.copy()

# %%
airbnb_peruibe_mar.head()
# Out:
#          id    check-in   check-out  \
# 0  41129581  2021-03-12  2021-03-14
# 1  30973729  2021-03-12  2021-03-14
# 2  39122509  2021-03-12  2021-03-14
# 3  29684686  2021-03-12  2021-03-14
# 4  46690967  2021-03-12  2021-03-14
#
#                                        titulo  \
# 0                   Quarto inteiro em Peruíbe
# 1  Casa de hóspedes inteira em Jardim Peruibe
# 2    Quarto inteiro em Parque Balneario Oasis
# 3                     Casa inteira em Peruíbe
# 4    Quarto inteiro em Parque Balneario Oasis
#
#                                             titulo_2  atributo_1 atributo_2  \
# 0   Pousada Suíte c/ Piscina e Ar Cond - 100m do mar  2 hóspedes   1 quarto
# 1                    Edícula na Praia de Peruíbe/SP.  3 hóspedes   1 quarto
# 2  Suíte 4 "Aconchego "c/piscina,ar cond 100 M Praia  2 hóspedes   1 quarto
# 3                        Casa do Carlos  em Peruíbe.  4 hóspedes    Estúdio
# 4                     Suíte 7 varanda " Por do Sol "  2 hóspedes   1 quarto
#
# ...

# %%
len(airbnb_peruibe_mar['id'].unique())
# Out:
# 40

# %%
#airbnb_praiagrande_fev['check-out'] = airbnb_praiagrande_fev['check-in']
#airbnb_praiagrande_fev['check-out'] = ['2021-02-28' if i == '2021-02-26' else '2021-02-21' for i in airbnb_praiagrande_fev['check-out']]

# %%
#airbnb_praiagrande_fev['check-out'].unique()
# Out:
# array(['2021-02-28', '2021-02-21'], dtype=object)

# %% [markdown]
# # Exportar para CSV

# %%
# Exportar para csv
airbnb_peruibe_mar.to_csv('airbnb_peruibe_mar.csv')
